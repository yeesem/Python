# %% [markdown]
# <a href="https://colab.research.google.com/github/yeesem/Python/blob/main/Data_Analytics_Tutorial_5_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/yeesem/Machine-Learning-Datasets/main/brfss.csv',index_col = None)
df.head()
# Out:
#    Unnamed: 0   age     weight2     wtyrago   wtkg2   htm3  sex
# 0           0  39.0   88.636364   88.636364   88.64  180.0    1
# 1           1  64.0   75.000000   84.545455   75.00  155.0    2
# 2           2  87.0   61.818182   63.636364   61.82    NaN    2
# 3           3  51.0  100.000000  100.000000  100.00  183.0    1
# 4           4  35.0   63.636364   61.363636   63.64  170.0    2

# %%
def cleanBRFSSData(df):
  df.drop(['Unnamed: 0','sex'],inplace = True,axis = 1)
  df.dropna(inplace = True)
  return df

# %%
# Drop the 'Unnamed: 0' and 'sex' columns
df.drop(['Unnamed: 0','sex'],inplace = True,axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414509 entries, 0 to 414508
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   age      410856 non-null  float64
#  1   weight2  398484 non-null  float64
#  2   wtyrago  390399 non-null  float64
#  3   wtkg2    398484 non-null  float64
#  4   htm3     409129 non-null  float64
# dtypes: float64(5)
# memory usage: 15.8 MB

# %%
# Drop the null value
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 385974 entries, 0 to 414506
# Data columns (total 5 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   age      385974 non-null  float64
#  1   weight2  385974 non-null  float64
#  2   wtyrago  385974 non-null  float64
#  3   wtkg2    385974 non-null  float64
#  4   htm3     385974 non-null  float64
# dtypes: float64(5)
# memory usage: 17.7 MB

# %%
df.head()
# Out:
#     age     weight2     wtyrago   wtkg2   htm3
# 0  39.0   88.636364   88.636364   88.64  180.0
# 1  64.0   75.000000   84.545455   75.00  155.0
# 3  51.0  100.000000  100.000000  100.00  183.0
# 4  35.0   63.636364   61.363636   63.64  170.0
# 5  62.0   70.454545   70.454545   70.45  173.0

# %%
df.describe()
# Out:
#                  age        weight2        wtyrago          wtkg2  \
# count  385974.000000  385974.000000  385974.000000  385974.000000
# mean       54.852487      79.061463      79.805186      79.061577
# std        16.685831      19.514283      20.578872      19.514227
# min        18.000000      20.000000      22.727273      20.000000
# 25%        43.000000      64.545455      64.545455      64.550000
# 50%        55.000000      77.272727      77.272727      77.270000
# 75%        67.000000      90.909091      90.909091      90.910000
# max        99.000000     300.000000     342.272727     300.000000
#
#                 htm3
# count  385974.000000
# mean      169.013441
# std        10.388870
# min        61.000000
# 25%       163.000000
# 50%       168.000000
# 75%       178.000000
# max       236.000000

# %%
# Find the mode and median of ages
print("Median : ",np.median(df['age']))
print("Mode : ",df['age'].mode()[0])
# Out:
# Median :  55.0
# Mode :  60.0
