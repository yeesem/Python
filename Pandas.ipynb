# %% [markdown]
# <a href="https://colab.research.google.com/github/yeesem2002/Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_data,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#d is a hash table - key - first columns, value - second column
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,3,4],['USA','Germany','Italy','Japan'])
ser2
# Out:
# USA        1
# Germany    2
# Italy      3
# Japan      4
# dtype: int64

# %%
ser1['USA']
# Out:
# 1

# %%
ser3 = pd.Series(data=labels)
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser3[0]
# Out:
# 'a'

# %%
#Data types will convert to float
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
ser1 - ser2
# Out:
# Germany    0.0
# Italy      NaN
# Japan      0.0
# USA        0.0
# USSR       NaN
# dtype: float64

# %% [markdown]
# # **Pandas - Dataframes**

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
#Data,Row names,Col names
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#Show w column
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df.W
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
 df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
#For axis 0 - row,1 - col, default - 0
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
#inplace - delete the data in the dataframe permanently
df.drop('new',axis=1,inplace=True)

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
df.shape
# Out:
# (5, 4)

# %%
#Access the row
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
#Access the row through index
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
#Access the data of row B, column Y
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(np.random.randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True  False  False   True
# C   True  False  False  False
# D   True  False   True   True
# E  False   True  False   True

# %%
booldf = df > 0

# %%
df[booldf]
# Out:
#           W         X         Y         Z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.196800       NaN  0.000366
# B  1.025984       NaN       NaN  0.649826
# C  2.154846       NaN       NaN       NaN
# D  0.147027       NaN  0.558769  1.024810
# E       NaN  1.862864       NaN  0.610478

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
df[['W']] > 0
# Out:
#        W
# A  False
# B   True
# C   True
# D   True
# E  False

# %%
df['W'] > 0
# Out:
# A    False
# B     True
# C     True
# D     True
# E    False
# Name: W, dtype: bool

# %%
df['W']
# Out:
# A   -0.993263
# B    1.025984
# C    2.154846
# D    0.147027
# E   -0.925874
# Name: W, dtype: float64

# %%
#Get the entire dataframe where the W > 0
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df[df['Z']<0]
# Out:
#           W         X         Y         Z
# C  2.154846 -0.610259 -0.755325 -0.346419

# %%
resultdf = df[df['W']>0]

# %%
resultdf
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
resultdf['X']
# Out:
# B   -0.156598
# C   -0.610259
# D   -0.479448
# Name: X, dtype: float64

# %%
df[df['W']>0][['X']]
# Out:
#           X
# B -0.156598
# C -0.610259
# D -0.479448
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4481951638201762368 = autoviz.get_df('df_4481951638201762368')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4481951638201762368, *['X'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# ...

# %%
df[df['W']>0][['X','Y']]
# Out:
#           X         Y
# B -0.156598 -0.031579
# C -0.610259 -0.755325
# D -0.479448  0.558769

# %%
#Need to use & instead of "and"
#Need to use | for "or"
df[df['W']>0 & (df['Y']>1)]
# Out:
#           W         X         Y         Z
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.993263  0.196800 -1.136645  0.000366
# 1     B  1.025984 -0.156598 -0.031579  0.649826
# 2     C  2.154846 -0.610259 -0.755325 -0.346419
# 3     D  0.147027 -0.479448  0.558769  1.024810
# 4     E -0.925874  1.862864 -1.133817  0.610478

# %%
df
# Out:
#           W         X         Y         Z
# A -0.993263  0.196800 -1.136645  0.000366
# B  1.025984 -0.156598 -0.031579  0.649826
# C  2.154846 -0.610259 -0.755325 -0.346419
# D  0.147027 -0.479448  0.558769  1.024810
# E -0.925874  1.862864 -1.133817  0.610478

# %%
newind = 'CA NY WY OR CO'.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.993263  0.196800 -1.136645  0.000366     CA
# B  1.025984 -0.156598 -0.031579  0.649826     NY
# C  2.154846 -0.610259 -0.755325 -0.346419     WY
# D  0.147027 -0.479448  0.558769  1.024810     OR
# E -0.925874  1.862864 -1.133817  0.610478     CO

# %%
df.set_index('States',inplace = True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA     -0.993263  0.196800 -1.136645  0.000366
# NY      1.025984 -0.156598 -0.031579  0.649826
# WY      2.154846 -0.610259 -0.755325 -0.346419
# OR      0.147027 -0.479448  0.558769  1.024810
# CO     -0.925874  1.862864 -1.133817  0.610478

# %%
#Index level
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]

#Group the data of inside and outside
hier_index = list(zip(outside,inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1  0.386030  2.084019
#    2 -0.376519  0.230336
#    3  0.681209  1.035125
# G2 1 -0.031160  1.939932
#    2 -1.005187 -0.741790
#    3  0.187125 -0.732845

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.386030  2.084019
# 2 -0.376519  0.230336
# 3  0.681209  1.035125

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.386030
# B    2.084019
# Name: 1, dtype: float64

# %%
df['A']
# Out:
# G1  1    0.386030
#     2   -0.376519
#     3    0.681209
# G2  1   -0.031160
#     2   -1.005187
#     3    0.187125
# Name: A, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    0.386030  2.084019
#        2   -0.376519  0.230336
#        3    0.681209  1.035125
# G2     1   -0.031160  1.939932
#        2   -1.005187 -0.741790
#        3    0.187125 -0.732845

# %%
df.loc['G2'].loc[2,'B']
# Out:
# -0.7417897046689249

# %%
df.xs
# Out:
# <bound method NDFrame.xs of                    A         B
# Groups Num
# G1     1    0.386030  2.084019
#        2   -0.376519  0.230336
#        3    0.681209  1.035125
# G2     1   -0.031160  1.939932
#        2   -1.005187 -0.741790
#        3    0.187125 -0.732845>

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.386030  2.084019
# 2   -0.376519  0.230336
# 3    0.681209  1.035125

# %%
df.xs(1,level = 'Num')
# Out:
#               A         B
# Groups
# G1      0.38603  2.084019
# G2     -0.03116  1.939932

# %%
df.xs(1,level = 'Num')>0
# Out:
#             A     B
# Groups
# G1       True  True
# G2      False  True

# %% [markdown]
# # **Missing Data**

# %%
d = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.fillna(value = 'FILL VALUE')
# Out:
#             A           B  C
# 0         1.0         5.0  1
# 1         2.0  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
#Fill the null value in column A with mean value of column A
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %% [markdown]
# # **Groupby**

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
        'Person':['Sam','Charlie','Amy','Vanessa','Garl','Sarah'],
        'Sales':[200,120,340,124,243,350]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Garl    243
# 5      FB    Sarah    350

# %%
byComp = df.groupby('Company')

# %%
byComp

# %%
#Pandas automatically ignore the non-numerical data
byComp.mean()
# Out:
# <ipython-input-124-97eff5e58c01>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   byComp.mean()
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
byComp.sum()
# Out:
# <ipython-input-125-f8846100a49e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   byComp.sum()
#          Sales
# Company
# FB         593
# GOOG       320
# MSFT       464

# %%
byComp.std()
# Out:
# <ipython-input-126-8353397b7a0a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   byComp.std()
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
byComp.sum().loc['FB']
# Out:
# <ipython-input-127-8f45b54782ef>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   byComp.sum().loc['FB']
# Sales    593
# Name: FB, dtype: int64

# %%
df.groupby('Company').sum().loc['GOOG']
# Out:
# <ipython-input-128-60ae67ce58db>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Company').sum().loc['GOOG']
# Sales    320
# Name: GOOG, dtype: int64

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
df.groupby('Company').max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df.groupby('Company').min()
# Out:
#           Person  Sales
# Company
# FB          Garl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().transpose()
# Out:
# Company              FB        GOOG        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df.groupby('Company').describe().transpose()['FB']
# Out:
# Sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# Name: FB, dtype: float64

# %% [markdown]
# # **Merging,Joining & Concatenating**

# %%
df1 = pd.DataFrame({
    'A' : ['A0','A1','A2','A3'],
    'B' : ['B0','B1','B2','B3'],
    'C' : ['C0','C1','C2','C3'],
    'D' : ['D0','D1','D2','D3']},
    index = [0,1,2,3]
)

# %%
df2 = pd.DataFrame({
    'A' : ['A4','A5','A6','A7'],
    'B' : ['B4','B5','B6','B7'],
    'C' : ['C4','C5','C6','C7'],
    'D' : ['D4','D5','D6','D7']},
    index = [4,5,6,7]
)

# %%
df3 = pd.DataFrame({
    'A' : ['A8','A9','A10','A11'],
    'B' : ['B8','B9','B10','B11'],
    'C' : ['C8','C9','C10','C11'],
    'D' : ['D8','D9','D10','D11']},
    index = [8,9,10,11]
)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
#concatenation
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis = 1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({
    'key' : ['K0','K1','K2','K3'],
    'A' : ['A0','A1','A2','A3'],
    'B' : ['B0','B1','B2','B3']
})

# %%
right = pd.DataFrame({
    'key' : ['K0','K1','K2','K3'],
    'C' : ['C0','C1','C2','C3'],
    'D' : ['D0','D1','D2','D3']
})

# %%
pd.concat([left,right],axis=1)
# Out:
#   key   A   B key   C   D
# 0  K0  A0  B0  K0  C0  D0
# 1  K1  A1  B1  K1  C1  D1
# 2  K2  A2  B2  K2  C2  D2
# 3  K3  A3  B3  K3  C3  D3

# %%
#Merging
pd.merge(left,right,how='inner',on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# Both join and merge can be used to combines two dataframes but the join method combines two dataframes on the basis of their indexes whereas the merge method is more versatile and allows us to specify columns beside the index to join on for both dataframes.

# %%
#Joining
#Need to specify index to join
left = pd.DataFrame({
    'A' : ['A0','A1','A2'],
    'B' : ['B0','B1','B2']},
    index = ['K0','K1','K2']
)

# %%
right = pd.DataFrame({
    'C' : ['C0','C1','C2'],
    'D' : ['D0','D2','D2']},
    index = ['K0','K2','K3']
)

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D2

# %% [markdown]
# # **Operations**

# %%
df = pd.DataFrame({
    'col1' : [1,2,3,4],
    'col2' : [444,555,666,444],
    'col3' : ['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[df['col1']>2]
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col1']>2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: col1, dtype: bool

# %%
df[(df['col1']>2) & (df['col2']==444)]
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
def times2(x):
  return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len)
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col3'].apply(lambda x : x*2)

# %%
df.drop('col1',axis=1)
# Out:
#    col2 col3
# 0   444  abc
# 1   555  def
# 2   666  ghi
# 3   444  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.sort_values(by='col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
data = {
        'A' : ['foo','foo','foo','bar','bar','bar'],
        'B' : ['one','one','two','two','one','one'],
        'C' : ['x','y','x','y','x','y'],
        'D' : [1,3,2,5,4,1],
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN
